# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as npimg
import os

## Keras
import keras
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Lambda, Conv2D, Convolution2D, MaxPooling2D, Dropout, Flatten, Dense
from keras.utils import multi_gpu_model
import keras.backend.tensorflow_backend as tfback
import tensorflow as tf

import cv2
import pandas as pd
import random
import ntpath

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split


from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS = 66, 200, 3
INPUT_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)

# %%
columns = ["img","steering"]
data = pd.read_csv(r'/home/u43783/driving_dataset/data.txt', sep = " ", names = columns)

# %%
datadir = '/home/u43783/driving_dataset'

# %%
def load_img_steering(datadir, df):
  """Get img and steering data into arrays"""
  image_path = []
  steering = []
  for i in range(len(data)):
    indexed_data = data.iloc[i]
    center = indexed_data[0]
    image_path.append(os.path.join(datadir, center.strip()))
    steering.append(float(indexed_data[1]))
  image_paths = np.asarray(image_path)
  steerings = np.asarray(steering)
  return image_paths, steerings

image_paths, steerings = load_img_steering(datadir , data)

# %%
X_train, X_valid, Y_train, Y_valid = train_test_split(image_paths, steerings, test_size=0.2, random_state=0)

# %%
def img_preprocess(img):
  """Take in path of img, returns preprocessed image"""
  img = npimg.imread(img)
  # Cropping the image
  img = img[60:-25, :, :]
  # Resizing the image
  img = cv2.resize(img, (IMAGE_WIDTH, IMAGE_HEIGHT), cv2.INTER_AREA)
  # Converting the image to YUV
  img = cv2.cvtColor(img, cv2.COLOR_RGB2YUV)
    
  return img

# %%
X_train = np.array(list(map(img_preprocess, X_train)))
X_valid = np.array(list(map(img_preprocess, X_valid)))

# %%
def nvidia_model():
  model = Sequential()
  model.add(Lambda(lambda x: x/127.5-1.0, input_shape=INPUT_SHAPE))
  model.add(Conv2D(24, 5, 5, activation='relu', subsample=(2, 2)))
  model.add(Conv2D(36, 5, 5, activation='relu', subsample=(2, 2)))
  model.add(Conv2D(48, 5, 5, activation='relu', subsample=(2, 2)))
  model.add(Conv2D(64, 3, 3, activation='relu'))
  model.add(Conv2D(64, 3, 3, activation='relu'))
  #model.add(Dropout(0.5))
  model.add(Flatten())
  model.add(Dense(100, activation='relu'))
  model.add(Dense(50, activation='relu'))
  model.add(Dense(10, activation='relu'))
  model.add(Dense(1))
  # model.summary()
  optimizer = Adam(lr=1e-4)
  #model = multi_gpu_model(model, gpus = 2)
  model.compile(loss='mse', optimizer=optimizer, metrics=['mean_squared_error'])
  # model.compile(loss='mse', optimizer=optimizer, metrics=['mean_squared_error'])
  return model

# %%
model = nvidia_model()

print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_1 (Lambda)            (None, 66, 200, 3)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 31, 98, 24)        1824
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 47, 36)        21636
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 22, 48)         43248
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 20, 64)         27712
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 1, 18, 64)         36928
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               115300
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 252,219
# Trainable params: 252,219
# Non-trainable params: 0
# _________________________________________________________________
# None
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (5, 5), activation="relu", strides=(2, 2))`
#   after removing the cwd from sys.path.
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(36, (5, 5), activation="relu", strides=(2, 2))`
#   """
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (5, 5), activation="relu", strides=(2, 2))`
#
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
#   import sys
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`

# %%
filepath="base_cnn_1e4.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

history = model.fit(X_train, Y_train, epochs=100, validation_data=(X_valid, Y_valid), batch_size=128, verbose=1, shuffle=1, callbacks=callbacks_list)
# model.save("base_cnn_1e4.h5")
# print("model saved")
# Out:
# Train on 36324 samples, validate on 9082 samples
# Epoch 1/100
# 36324/36324 [==============================] - 46s 1ms/step - loss: 872.6479 - mean_squared_error: 872.6476 - val_loss: 908.8531 - val_mean_squared_error: 908.8531
#
# Epoch 00001: val_loss improved from inf to 908.85315, saving model to base_cnn_1e4.hdf5
# Epoch 2/100
# 36324/36324 [==============================] - 45s 1ms/step - loss: 747.8215 - mean_squared_error: 747.8217 - val_loss: 739.5393 - val_mean_squared_error: 739.5393
#
# Epoch 00002: val_loss improved from 908.85315 to 739.53931, saving model to base_cnn_1e4.hdf5
# Epoch 3/100
# 36324/36324 [==============================] - 45s 1ms/step - loss: 617.7195 - mean_squared_error: 617.7195 - val_loss: 596.0142 - val_mean_squared_error: 596.0142
#
# Epoch 00003: val_loss improved from 739.53931 to 596.01417, saving model to base_cnn_1e4.hdf5
# Epoch 4/100
# 36324/36324 [==============================] - 45s 1ms/step - loss: 478.0278 - mean_squared_error: 478.0274 - val_loss: 479.4607 - val_mean_squared_error: 479.4608
#
# Epoch 00004: val_loss improved from 596.01417 to 479.46072, saving model to base_cnn_1e4.hdf5
# Epoch 5/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 389.3926 - mean_squared_error: 389.3925 - val_loss: 383.8137 - val_mean_squared_error: 383.8138
#
# Epoch 00005: val_loss improved from 479.46072 to 383.81373, saving model to base_cnn_1e4.hdf5
# Epoch 6/100
# 36324/36324 [==============================] - 45s 1ms/step - loss: 313.2655 - mean_squared_error: 313.2654 - val_loss: 307.9440 - val_mean_squared_error: 307.9439
#
# Epoch 00006: val_loss improved from 383.81373 to 307.94395, saving model to base_cnn_1e4.hdf5
# Epoch 7/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 259.5529 - mean_squared_error: 259.5529 - val_loss: 261.7225 - val_mean_squared_error: 261.7226
#
# Epoch 00007: val_loss improved from 307.94395 to 261.72254, saving model to base_cnn_1e4.hdf5
# Epoch 8/100
# 36324/36324 [==============================] - 42s 1ms/step - loss: 211.7837 - mean_squared_error: 211.7837 - val_loss: 218.0990 - val_mean_squared_error: 218.0991
#
# Epoch 00008: val_loss improved from 261.72254 to 218.09904, saving model to base_cnn_1e4.hdf5
# Epoch 9/100
# 36324/36324 [==============================] - 42s 1ms/step - loss: 180.0967 - mean_squared_error: 180.0968 - val_loss: 194.6969 - val_mean_squared_error: 194.6969
#
# Epoch 00009: val_loss improved from 218.09904 to 194.69693, saving model to base_cnn_1e4.hdf5
# Epoch 10/100
# 36324/36324 [==============================] - 42s 1ms/step - loss: 156.0656 - mean_squared_error: 156.0655 - val_loss: 147.8399 - val_mean_squared_error: 147.8399
#
# Epoch 00010: val_loss improved from 194.69693 to 147.83989, saving model to base_cnn_1e4.hdf5
# Epoch 11/100
# 36324/36324 [==============================] - 42s 1ms/step - loss: 135.2540 - mean_squared_error: 135.2540 - val_loss: 136.3880 - val_mean_squared_error: 136.3880
#
# Epoch 00011: val_loss improved from 147.83989 to 136.38801, saving model to base_cnn_1e4.hdf5
# Epoch 12/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 120.7242 - mean_squared_error: 120.7242 - val_loss: 114.6110 - val_mean_squared_error: 114.6110
#
# Epoch 00012: val_loss improved from 136.38801 to 114.61102, saving model to base_cnn_1e4.hdf5
# Epoch 13/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 105.0709 - mean_squared_error: 105.0709 - val_loss: 115.4076 - val_mean_squared_error: 115.4076
#
# Epoch 00013: val_loss did not improve from 114.61102
# Epoch 14/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 98.7600 - mean_squared_error: 98.7600 - val_loss: 101.4951 - val_mean_squared_error: 101.4952
#
# Epoch 00014: val_loss improved from 114.61102 to 101.49515, saving model to base_cnn_1e4.hdf5
# Epoch 15/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 92.4520 - mean_squared_error: 92.4520 - val_loss: 87.5772 - val_mean_squared_error: 87.5772
#
# Epoch 00015: val_loss improved from 101.49515 to 87.57721, saving model to base_cnn_1e4.hdf5
# Epoch 16/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 83.4876 - mean_squared_error: 83.4876 - val_loss: 140.7160 - val_mean_squared_error: 140.7160
#
# Epoch 00016: val_loss did not improve from 87.57721
# Epoch 17/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 82.3179 - mean_squared_error: 82.3179 - val_loss: 78.8144 - val_mean_squared_error: 78.8144
#
# Epoch 00017: val_loss improved from 87.57721 to 78.81440, saving model to base_cnn_1e4.hdf5
# Epoch 18/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 75.3270 - mean_squared_error: 75.3270 - val_loss: 73.2851 - val_mean_squared_error: 73.2851
#
# Epoch 00018: val_loss improved from 78.81440 to 73.28512, saving model to base_cnn_1e4.hdf5
# Epoch 19/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 73.0471 - mean_squared_error: 73.0471 - val_loss: 70.4082 - val_mean_squared_error: 70.4082
#
# Epoch 00019: val_loss improved from 73.28512 to 70.40818, saving model to base_cnn_1e4.hdf5
# Epoch 20/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 64.7696 - mean_squared_error: 64.7696 - val_loss: 109.5597 - val_mean_squared_error: 109.5597
#
# Epoch 00020: val_loss did not improve from 70.40818
# Epoch 21/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 67.6396 - mean_squared_error: 67.6396 - val_loss: 73.7514 - val_mean_squared_error: 73.7514
#
# Epoch 00021: val_loss did not improve from 70.40818
# Epoch 22/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 61.5791 - mean_squared_error: 61.5791 - val_loss: 75.1175 - val_mean_squared_error: 75.1175
#
# Epoch 00022: val_loss did not improve from 70.40818
# Epoch 23/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 62.2778 - mean_squared_error: 62.2778 - val_loss: 57.4609 - val_mean_squared_error: 57.4609
#
# Epoch 00023: val_loss improved from 70.40818 to 57.46091, saving model to base_cnn_1e4.hdf5
# Epoch 24/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 58.2336 - mean_squared_error: 58.2336 - val_loss: 54.7396 - val_mean_squared_error: 54.7396
#
# Epoch 00024: val_loss improved from 57.46091 to 54.73956, saving model to base_cnn_1e4.hdf5
# Epoch 25/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 52.1099 - mean_squared_error: 52.1099 - val_loss: 65.6837 - val_mean_squared_error: 65.6837
#
# Epoch 00025: val_loss did not improve from 54.73956
# Epoch 26/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 56.4343 - mean_squared_error: 56.4343 - val_loss: 57.7950 - val_mean_squared_error: 57.7950
#
# Epoch 00026: val_loss did not improve from 54.73956
# Epoch 27/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 55.1700 - mean_squared_error: 55.1700 - val_loss: 49.5523 - val_mean_squared_error: 49.5523
#
# Epoch 00027: val_loss improved from 54.73956 to 49.55231, saving model to base_cnn_1e4.hdf5
# Epoch 28/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 53.4969 - mean_squared_error: 53.4969 - val_loss: 54.6716 - val_mean_squared_error: 54.6716
#
# Epoch 00028: val_loss did not improve from 49.55231
# Epoch 29/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 49.9044 - mean_squared_error: 49.9044 - val_loss: 47.1427 - val_mean_squared_error: 47.1427
#
# Epoch 00029: val_loss improved from 49.55231 to 47.14269, saving model to base_cnn_1e4.hdf5
# Epoch 30/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 49.0144 - mean_squared_error: 49.0144 - val_loss: 48.3472 - val_mean_squared_error: 48.3472
#
# Epoch 00030: val_loss did not improve from 47.14269
# Epoch 31/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 51.4167 - mean_squared_error: 51.4167 - val_loss: 45.7436 - val_mean_squared_error: 45.7436
#
# Epoch 00031: val_loss improved from 47.14269 to 45.74360, saving model to base_cnn_1e4.hdf5
# Epoch 32/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 49.0160 - mean_squared_error: 49.0160 - val_loss: 43.7198 - val_mean_squared_error: 43.7198
#
# Epoch 00032: val_loss improved from 45.74360 to 43.71977, saving model to base_cnn_1e4.hdf5
# Epoch 33/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 45.3962 - mean_squared_error: 45.3962 - val_loss: 45.3073 - val_mean_squared_error: 45.3073
#
# Epoch 00033: val_loss did not improve from 43.71977
# Epoch 34/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 46.0182 - mean_squared_error: 46.0182 - val_loss: 44.4463 - val_mean_squared_error: 44.4463
#
# Epoch 00034: val_loss did not improve from 43.71977
# Epoch 35/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 43.3771 - mean_squared_error: 43.3772 - val_loss: 49.3671 - val_mean_squared_error: 49.3671
#
# Epoch 00035: val_loss did not improve from 43.71977
# Epoch 36/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 42.6968 - mean_squared_error: 42.6968 - val_loss: 44.9511 - val_mean_squared_error: 44.9511
#
# Epoch 00036: val_loss did not improve from 43.71977
# Epoch 37/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 44.4585 - mean_squared_error: 44.4585 - val_loss: 44.2744 - val_mean_squared_error: 44.2744
#
# Epoch 00037: val_loss did not improve from 43.71977
# Epoch 38/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 40.9738 - mean_squared_error: 40.9738 - val_loss: 38.1570 - val_mean_squared_error: 38.1570
#
# Epoch 00038: val_loss improved from 43.71977 to 38.15704, saving model to base_cnn_1e4.hdf5
# Epoch 39/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 41.4069 - mean_squared_error: 41.4069 - val_loss: 44.9433 - val_mean_squared_error: 44.9434
#
# Epoch 00039: val_loss did not improve from 38.15704
# Epoch 40/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 43.5187 - mean_squared_error: 43.5187 - val_loss: 39.6754 - val_mean_squared_error: 39.6754
#
# Epoch 00040: val_loss did not improve from 38.15704
# Epoch 41/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 37.2538 - mean_squared_error: 37.2538 - val_loss: 48.4561 - val_mean_squared_error: 48.4561
#
# Epoch 00041: val_loss did not improve from 38.15704
# Epoch 42/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 39.2323 - mean_squared_error: 39.2323 - val_loss: 43.6543 - val_mean_squared_error: 43.6543
#
# Epoch 00042: val_loss did not improve from 38.15704
# Epoch 43/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 36.6416 - mean_squared_error: 36.6416 - val_loss: 41.9245 - val_mean_squared_error: 41.9245
#
# Epoch 00043: val_loss did not improve from 38.15704
# Epoch 44/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 41.3867 - mean_squared_error: 41.3868 - val_loss: 40.9805 - val_mean_squared_error: 40.9805
#
# Epoch 00044: val_loss did not improve from 38.15704
# Epoch 45/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 36.9063 - mean_squared_error: 36.9063 - val_loss: 40.3632 - val_mean_squared_error: 40.3632
#
# Epoch 00045: val_loss did not improve from 38.15704
# Epoch 46/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 34.7303 - mean_squared_error: 34.7303 - val_loss: 49.4843 - val_mean_squared_error: 49.4843
#
# Epoch 00046: val_loss did not improve from 38.15704
# Epoch 47/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 38.0251 - mean_squared_error: 38.0251 - val_loss: 36.0252 - val_mean_squared_error: 36.0252
#
# Epoch 00047: val_loss improved from 38.15704 to 36.02525, saving model to base_cnn_1e4.hdf5
# Epoch 48/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 36.8605 - mean_squared_error: 36.8605 - val_loss: 40.2178 - val_mean_squared_error: 40.2178
#
# Epoch 00048: val_loss did not improve from 36.02525
# Epoch 49/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 34.5904 - mean_squared_error: 34.5904 - val_loss: 34.2173 - val_mean_squared_error: 34.2173
#
# Epoch 00049: val_loss improved from 36.02525 to 34.21733, saving model to base_cnn_1e4.hdf5
# Epoch 50/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 35.0808 - mean_squared_error: 35.0808 - val_loss: 49.3906 - val_mean_squared_error: 49.3906
#
# Epoch 00050: val_loss did not improve from 34.21733
# Epoch 51/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 35.0518 - mean_squared_error: 35.0518 - val_loss: 38.8915 - val_mean_squared_error: 38.8915
#
# Epoch 00051: val_loss did not improve from 34.21733
# Epoch 52/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 34.3437 - mean_squared_error: 34.3436 - val_loss: 48.0260 - val_mean_squared_error: 48.0260
#
# Epoch 00052: val_loss did not improve from 34.21733
# Epoch 53/100
# 36324/36324 [==============================] - 42s 1ms/step - loss: 33.0320 - mean_squared_error: 33.0320 - val_loss: 32.8048 - val_mean_squared_error: 32.8048
#
# Epoch 00053: val_loss improved from 34.21733 to 32.80483, saving model to base_cnn_1e4.hdf5
# Epoch 54/100
# 36324/36324 [==============================] - 42s 1ms/step - loss: 32.4494 - mean_squared_error: 32.4494 - val_loss: 36.0608 - val_mean_squared_error: 36.0608
#
# Epoch 00054: val_loss did not improve from 32.80483
# Epoch 55/100
# 36324/36324 [==============================] - 42s 1ms/step - loss: 34.9628 - mean_squared_error: 34.9628 - val_loss: 38.2321 - val_mean_squared_error: 38.2321
#
# Epoch 00055: val_loss did not improve from 32.80483
# Epoch 56/100
# 36324/36324 [==============================] - 42s 1ms/step - loss: 30.7197 - mean_squared_error: 30.7197 - val_loss: 42.9608 - val_mean_squared_error: 42.9608
#
# Epoch 00056: val_loss did not improve from 32.80483
# Epoch 57/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 29.6265 - mean_squared_error: 29.6265 - val_loss: 37.9381 - val_mean_squared_error: 37.9381
#
# Epoch 00057: val_loss did not improve from 32.80483
# Epoch 58/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 36.1125 - mean_squared_error: 36.1125 - val_loss: 43.8159 - val_mean_squared_error: 43.8159
#
# Epoch 00058: val_loss did not improve from 32.80483
# Epoch 59/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 31.7306 - mean_squared_error: 31.7305 - val_loss: 36.1768 - val_mean_squared_error: 36.1768
#
# Epoch 00059: val_loss did not improve from 32.80483
# Epoch 60/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 29.7087 - mean_squared_error: 29.7087 - val_loss: 48.1328 - val_mean_squared_error: 48.1328
#
# Epoch 00060: val_loss did not improve from 32.80483
# Epoch 61/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 31.1436 - mean_squared_error: 31.1436 - val_loss: 36.5836 - val_mean_squared_error: 36.5836
#
# Epoch 00061: val_loss did not improve from 32.80483
# Epoch 62/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 29.5832 - mean_squared_error: 29.5832 - val_loss: 44.4229 - val_mean_squared_error: 44.4229
#
# Epoch 00062: val_loss did not improve from 32.80483
# Epoch 63/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 28.1835 - mean_squared_error: 28.1835 - val_loss: 41.4613 - val_mean_squared_error: 41.4613
#
# Epoch 00063: val_loss did not improve from 32.80483
# Epoch 64/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 29.9765 - mean_squared_error: 29.9765 - val_loss: 33.1574 - val_mean_squared_error: 33.1574
#
# Epoch 00064: val_loss did not improve from 32.80483
# Epoch 65/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 27.8348 - mean_squared_error: 27.8348 - val_loss: 33.5368 - val_mean_squared_error: 33.5368
#
# Epoch 00065: val_loss did not improve from 32.80483
# Epoch 66/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 28.5417 - mean_squared_error: 28.5417 - val_loss: 34.3306 - val_mean_squared_error: 34.3306
#
# Epoch 00066: val_loss did not improve from 32.80483
# Epoch 67/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 26.9326 - mean_squared_error: 26.9326 - val_loss: 36.8393 - val_mean_squared_error: 36.8393
#
# Epoch 00067: val_loss did not improve from 32.80483
# Epoch 68/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 27.3406 - mean_squared_error: 27.3406 - val_loss: 35.2880 - val_mean_squared_error: 35.2880
#
# Epoch 00068: val_loss did not improve from 32.80483
# Epoch 69/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 26.4444 - mean_squared_error: 26.4444 - val_loss: 34.4269 - val_mean_squared_error: 34.4269
#
# Epoch 00069: val_loss did not improve from 32.80483
# Epoch 70/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 25.4738 - mean_squared_error: 25.4738 - val_loss: 35.8897 - val_mean_squared_error: 35.8896
#
# Epoch 00070: val_loss did not improve from 32.80483
# Epoch 71/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 28.0528 - mean_squared_error: 28.0528 - val_loss: 35.8702 - val_mean_squared_error: 35.8702
#
# Epoch 00071: val_loss did not improve from 32.80483
# Epoch 72/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 24.5880 - mean_squared_error: 24.5880 - val_loss: 40.0677 - val_mean_squared_error: 40.0677
#
# Epoch 00072: val_loss did not improve from 32.80483
# Epoch 73/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 26.5531 - mean_squared_error: 26.5531 - val_loss: 30.0795 - val_mean_squared_error: 30.0795
#
# Epoch 00073: val_loss improved from 32.80483 to 30.07949, saving model to base_cnn_1e4.hdf5
# Epoch 74/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 25.5840 - mean_squared_error: 25.5840 - val_loss: 37.2965 - val_mean_squared_error: 37.2965
#
# Epoch 00074: val_loss did not improve from 30.07949
# Epoch 75/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 24.6912 - mean_squared_error: 24.6912 - val_loss: 46.8679 - val_mean_squared_error: 46.8679
#
# Epoch 00075: val_loss did not improve from 30.07949
# Epoch 76/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 23.6346 - mean_squared_error: 23.6346 - val_loss: 36.9066 - val_mean_squared_error: 36.9067
#
# Epoch 00076: val_loss did not improve from 30.07949
# Epoch 77/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 24.8921 - mean_squared_error: 24.8921 - val_loss: 49.8317 - val_mean_squared_error: 49.8317
#
# Epoch 00077: val_loss did not improve from 30.07949
# Epoch 78/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 24.8182 - mean_squared_error: 24.8182 - val_loss: 33.5213 - val_mean_squared_error: 33.5212
#
# Epoch 00078: val_loss did not improve from 30.07949
# Epoch 79/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 24.0452 - mean_squared_error: 24.0452 - val_loss: 37.7190 - val_mean_squared_error: 37.7190
#
# Epoch 00079: val_loss did not improve from 30.07949
# Epoch 80/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 24.0932 - mean_squared_error: 24.0932 - val_loss: 37.6401 - val_mean_squared_error: 37.6401
#
# Epoch 00080: val_loss did not improve from 30.07949
# Epoch 81/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 23.3028 - mean_squared_error: 23.3028 - val_loss: 52.6102 - val_mean_squared_error: 52.6102
#
# Epoch 00081: val_loss did not improve from 30.07949
# Epoch 82/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 24.7206 - mean_squared_error: 24.7206 - val_loss: 33.8388 - val_mean_squared_error: 33.8388
#
# Epoch 00082: val_loss did not improve from 30.07949
# Epoch 83/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 23.6318 - mean_squared_error: 23.6318 - val_loss: 52.0054 - val_mean_squared_error: 52.0054
#
# Epoch 00083: val_loss did not improve from 30.07949
# Epoch 84/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 22.6375 - mean_squared_error: 22.6375 - val_loss: 48.7484 - val_mean_squared_error: 48.7484
#
# Epoch 00084: val_loss did not improve from 30.07949
# Epoch 85/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 24.3443 - mean_squared_error: 24.3443 - val_loss: 33.1744 - val_mean_squared_error: 33.1744
#
# Epoch 00085: val_loss did not improve from 30.07949
# Epoch 86/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 23.3469 - mean_squared_error: 23.3469 - val_loss: 40.8544 - val_mean_squared_error: 40.8544
#
# Epoch 00086: val_loss did not improve from 30.07949
# Epoch 87/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 23.6318 - mean_squared_error: 23.6318 - val_loss: 34.9112 - val_mean_squared_error: 34.9112
#
# Epoch 00087: val_loss did not improve from 30.07949
# Epoch 88/100
# 36324/36324 [==============================] - 42s 1ms/step - loss: 22.1903 - mean_squared_error: 22.1903 - val_loss: 35.0435 - val_mean_squared_error: 35.0435
#
# Epoch 00088: val_loss did not improve from 30.07949
# Epoch 89/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 21.8957 - mean_squared_error: 21.8957 - val_loss: 35.3397 - val_mean_squared_error: 35.3397
#
# Epoch 00089: val_loss did not improve from 30.07949
# Epoch 90/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 21.9598 - mean_squared_error: 21.9597 - val_loss: 35.2936 - val_mean_squared_error: 35.2936
#
# Epoch 00090: val_loss did not improve from 30.07949
# Epoch 91/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 22.9551 - mean_squared_error: 22.9551 - val_loss: 36.4618 - val_mean_squared_error: 36.4618
#
# Epoch 00091: val_loss did not improve from 30.07949
# Epoch 92/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 22.8966 - mean_squared_error: 22.8966 - val_loss: 36.9457 - val_mean_squared_error: 36.9457
#
# Epoch 00092: val_loss did not improve from 30.07949
# Epoch 93/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 20.3300 - mean_squared_error: 20.3300 - val_loss: 37.0788 - val_mean_squared_error: 37.0788
#
# Epoch 00093: val_loss did not improve from 30.07949
# Epoch 94/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 21.2117 - mean_squared_error: 21.2117 - val_loss: 29.2485 - val_mean_squared_error: 29.2485
#
# Epoch 00094: val_loss improved from 30.07949 to 29.24848, saving model to base_cnn_1e4.hdf5
# Epoch 95/100
# 36324/36324 [==============================] - 43s 1ms/step - loss: 20.3074 - mean_squared_error: 20.3074 - val_loss: 32.8138 - val_mean_squared_error: 32.8138
#
# Epoch 00095: val_loss did not improve from 29.24848
# Epoch 96/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 20.6625 - mean_squared_error: 20.6625 - val_loss: 36.2576 - val_mean_squared_error: 36.2576
#
# Epoch 00096: val_loss did not improve from 29.24848
# Epoch 97/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 21.4192 - mean_squared_error: 21.4192 - val_loss: 36.6539 - val_mean_squared_error: 36.6539
#
# Epoch 00097: val_loss did not improve from 29.24848
# Epoch 98/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 19.7679 - mean_squared_error: 19.7679 - val_loss: 30.0474 - val_mean_squared_error: 30.0474
#
# Epoch 00098: val_loss did not improve from 29.24848
# Epoch 99/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 19.9476 - mean_squared_error: 19.9476 - val_loss: 33.8077 - val_mean_squared_error: 33.8077
#
# Epoch 00099: val_loss did not improve from 29.24848
# Epoch 100/100
# 36324/36324 [==============================] - 44s 1ms/step - loss: 20.1176 - mean_squared_error: 20.1176 - val_loss: 42.7549 - val_mean_squared_error: 42.7549
#
# Epoch 00100: val_loss did not improve from 29.24848

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(3, 3), dpi=300, facecolor='w', edgecolor='k')

plt.plot(history.history['loss'], color = 'red')
plt.plot(history.history['val_loss'], color = 'green')
plt.title('NVIDIA''s end to end model with 1e4 learning rate')
plt.ylabel('Mean Squared Error')
plt.xlabel('Epochs')
plt.legend(['training_loss', 'validation_loss'], loc='upper right')
plt.savefig('NVIDIA_END_TO_END_1E4.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
def my_model():
  model = Sequential()
  model.add(Lambda(lambda x: x/127.5-1.0, input_shape=INPUT_SHAPE))
  model.add(Conv2D(24, 5, 5, activation='relu', subsample=(2, 2)))
  model.add(Conv2D(36, 5, 5, activation='relu', subsample=(2, 2)))
  model.add(Conv2D(48, 5, 5, activation='relu', subsample=(2, 2)))
  model.add(Conv2D(64, 3, 3, activation='relu'))
  model.add(Conv2D(64, 3, 3, activation='relu'))
  model.add(Conv2D(32, 1, 1, activation='relu'))
  
  model.add(Flatten())
  
  model.add(Dense(100, activation='relu'))
  model.add(Dense(50, activation='relu'))
  model.add(Dense(10, activation='relu'))
  model.add(Dense(1))
  
  optimizer = Adam(lr=1e-4)
  
  model.compile(loss='mse', optimizer=optimizer, metrics=['mean_squared_error'])
  
  return model

# %%
my_model = my_model()
print(my_model.summary())
# Out:
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (5, 5), activation="relu", strides=(2, 2))`
#   after removing the cwd from sys.path.
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(36, (5, 5), activation="relu", strides=(2, 2))`
#   """
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (5, 5), activation="relu", strides=(2, 2))`
#
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
#   import sys
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
#
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), activation="relu")`
#   if __name__ == '__main__':
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_1 (Lambda)            (None, 66, 200, 3)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 31, 98, 24)        1824
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 47, 36)        21636
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 22, 48)         43248
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 20, 64)         27712
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 1, 18, 64)         36928
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 1, 18, 32)         2080
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               57700
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 196,699
# Trainable params: 196,699
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
filepath="my_cnn_1e4.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]
history1 = my_model.fit(X_train, Y_train, epochs=100, validation_data=(X_valid, Y_valid), batch_size=128, verbose=1, shuffle=1, callbacks=callbacks_list)
# my_model.save("my_cnn_1e4.h5")
# print("my model saved")
# Out:
# Train on 36324 samples, validate on 9082 samples
# Epoch 1/100
# 36324/36324 [==============================] - 26s 722us/step - loss: 901.3348 - mean_squared_error: 901.3351 - val_loss: 883.6364 - val_mean_squared_error: 883.6365
#
# Epoch 00001: val_loss improved from inf to 883.63644, saving model to my_cnn_1e4.hdf5
# Epoch 2/100
# 36324/36324 [==============================] - 26s 703us/step - loss: 746.5467 - mean_squared_error: 746.5467 - val_loss: 750.2219 - val_mean_squared_error: 750.2219
#
# Epoch 00002: val_loss improved from 883.63644 to 750.22194, saving model to my_cnn_1e4.hdf5
# Epoch 3/100
# 36324/36324 [==============================] - 25s 688us/step - loss: 637.7617 - mean_squared_error: 637.7618 - val_loss: 656.1778 - val_mean_squared_error: 656.1778
#
# Epoch 00003: val_loss improved from 750.22194 to 656.17777, saving model to my_cnn_1e4.hdf5
# Epoch 4/100
# 36324/36324 [==============================] - 25s 693us/step - loss: 555.4882 - mean_squared_error: 555.4882 - val_loss: 570.3190 - val_mean_squared_error: 570.3190
#
# Epoch 00004: val_loss improved from 656.17777 to 570.31905, saving model to my_cnn_1e4.hdf5
# Epoch 5/100
# 36324/36324 [==============================] - 25s 684us/step - loss: 484.5405 - mean_squared_error: 484.5404 - val_loss: 530.8481 - val_mean_squared_error: 530.8481
#
# Epoch 00005: val_loss improved from 570.31905 to 530.84814, saving model to my_cnn_1e4.hdf5
# Epoch 6/100
# 36324/36324 [==============================] - 25s 687us/step - loss: 422.0392 - mean_squared_error: 422.0391 - val_loss: 458.2235 - val_mean_squared_error: 458.2234
#
# Epoch 00006: val_loss improved from 530.84814 to 458.22347, saving model to my_cnn_1e4.hdf5
# Epoch 7/100
# 36324/36324 [==============================] - 25s 685us/step - loss: 375.8059 - mean_squared_error: 375.8060 - val_loss: 387.5804 - val_mean_squared_error: 387.5804
#
# Epoch 00007: val_loss improved from 458.22347 to 387.58042, saving model to my_cnn_1e4.hdf5
# Epoch 8/100
# 36324/36324 [==============================] - 25s 685us/step - loss: 324.1720 - mean_squared_error: 324.1720 - val_loss: 346.2974 - val_mean_squared_error: 346.2974
#
# Epoch 00008: val_loss improved from 387.58042 to 346.29742, saving model to my_cnn_1e4.hdf5
# Epoch 9/100
# 36324/36324 [==============================] - 25s 684us/step - loss: 290.7253 - mean_squared_error: 290.7252 - val_loss: 291.4079 - val_mean_squared_error: 291.4080
#
# Epoch 00009: val_loss improved from 346.29742 to 291.40788, saving model to my_cnn_1e4.hdf5
# Epoch 10/100
# 36324/36324 [==============================] - 25s 680us/step - loss: 254.8371 - mean_squared_error: 254.8371 - val_loss: 267.8368 - val_mean_squared_error: 267.8367
#
# Epoch 00010: val_loss improved from 291.40788 to 267.83676, saving model to my_cnn_1e4.hdf5
# Epoch 11/100
# 36324/36324 [==============================] - 25s 686us/step - loss: 230.5810 - mean_squared_error: 230.5810 - val_loss: 252.7970 - val_mean_squared_error: 252.7970
#
# Epoch 00011: val_loss improved from 267.83676 to 252.79703, saving model to my_cnn_1e4.hdf5
# Epoch 12/100
# 36324/36324 [==============================] - 25s 680us/step - loss: 205.8676 - mean_squared_error: 205.8676 - val_loss: 233.0523 - val_mean_squared_error: 233.0523
#
# Epoch 00012: val_loss improved from 252.79703 to 233.05231, saving model to my_cnn_1e4.hdf5
# Epoch 13/100
# 36324/36324 [==============================] - 24s 674us/step - loss: 191.5511 - mean_squared_error: 191.5511 - val_loss: 204.0974 - val_mean_squared_error: 204.0974
#
# Epoch 00013: val_loss improved from 233.05231 to 204.09738, saving model to my_cnn_1e4.hdf5
# Epoch 14/100
# 36324/36324 [==============================] - 25s 680us/step - loss: 174.6073 - mean_squared_error: 174.6073 - val_loss: 182.4379 - val_mean_squared_error: 182.4379
#
# Epoch 00014: val_loss improved from 204.09738 to 182.43789, saving model to my_cnn_1e4.hdf5
# Epoch 15/100
# 36324/36324 [==============================] - 25s 686us/step - loss: 156.5577 - mean_squared_error: 156.5577 - val_loss: 182.8313 - val_mean_squared_error: 182.8313
#
# Epoch 00015: val_loss did not improve from 182.43789
# Epoch 16/100
# 36324/36324 [==============================] - 25s 676us/step - loss: 147.5501 - mean_squared_error: 147.5501 - val_loss: 153.9012 - val_mean_squared_error: 153.9012
#
# Epoch 00016: val_loss improved from 182.43789 to 153.90117, saving model to my_cnn_1e4.hdf5
# Epoch 17/100
# 36324/36324 [==============================] - 25s 675us/step - loss: 140.5119 - mean_squared_error: 140.5119 - val_loss: 149.6786 - val_mean_squared_error: 149.6785
#
# Epoch 00017: val_loss improved from 153.90117 to 149.67856, saving model to my_cnn_1e4.hdf5
# Epoch 18/100
# 36324/36324 [==============================] - 25s 679us/step - loss: 130.4342 - mean_squared_error: 130.4342 - val_loss: 143.9039 - val_mean_squared_error: 143.9039
#
# Epoch 00018: val_loss improved from 149.67856 to 143.90389, saving model to my_cnn_1e4.hdf5
# Epoch 19/100
# 36324/36324 [==============================] - 25s 678us/step - loss: 126.2762 - mean_squared_error: 126.2762 - val_loss: 130.4544 - val_mean_squared_error: 130.4544
#
# Epoch 00019: val_loss improved from 143.90389 to 130.45443, saving model to my_cnn_1e4.hdf5
# Epoch 20/100
# 36324/36324 [==============================] - 25s 687us/step - loss: 116.9885 - mean_squared_error: 116.9885 - val_loss: 129.4838 - val_mean_squared_error: 129.4838
#
# Epoch 00020: val_loss improved from 130.45443 to 129.48382, saving model to my_cnn_1e4.hdf5
# Epoch 21/100
# 36324/36324 [==============================] - 24s 670us/step - loss: 108.8310 - mean_squared_error: 108.8310 - val_loss: 122.7343 - val_mean_squared_error: 122.7343
#
# Epoch 00021: val_loss improved from 129.48382 to 122.73429, saving model to my_cnn_1e4.hdf5
# Epoch 22/100
# 36324/36324 [==============================] - 24s 674us/step - loss: 104.6420 - mean_squared_error: 104.6420 - val_loss: 120.5381 - val_mean_squared_error: 120.5382
#
# Epoch 00022: val_loss improved from 122.73429 to 120.53815, saving model to my_cnn_1e4.hdf5
# Epoch 23/100
# 36324/36324 [==============================] - 24s 672us/step - loss: 102.8178 - mean_squared_error: 102.8178 - val_loss: 111.0762 - val_mean_squared_error: 111.0762
#
# Epoch 00023: val_loss improved from 120.53815 to 111.07616, saving model to my_cnn_1e4.hdf5
# Epoch 24/100
# 36324/36324 [==============================] - 24s 671us/step - loss: 97.6848 - mean_squared_error: 97.6848 - val_loss: 137.0165 - val_mean_squared_error: 137.0165
#
# Epoch 00024: val_loss did not improve from 111.07616
# Epoch 25/100
# 36324/36324 [==============================] - 24s 671us/step - loss: 95.3418 - mean_squared_error: 95.3418 - val_loss: 100.0717 - val_mean_squared_error: 100.0717
#
# Epoch 00025: val_loss improved from 111.07616 to 100.07168, saving model to my_cnn_1e4.hdf5
# Epoch 26/100
# 36324/36324 [==============================] - 25s 679us/step - loss: 93.3550 - mean_squared_error: 93.3550 - val_loss: 96.2331 - val_mean_squared_error: 96.2331
#
# Epoch 00026: val_loss improved from 100.07168 to 96.23312, saving model to my_cnn_1e4.hdf5
# Epoch 27/100
# 36324/36324 [==============================] - 24s 673us/step - loss: 89.7283 - mean_squared_error: 89.7283 - val_loss: 108.6750 - val_mean_squared_error: 108.6750
#
# Epoch 00027: val_loss did not improve from 96.23312
# Epoch 28/100
# 36324/36324 [==============================] - 25s 680us/step - loss: 85.3598 - mean_squared_error: 85.3598 - val_loss: 116.2142 - val_mean_squared_error: 116.2142
#
# Epoch 00028: val_loss did not improve from 96.23312
# Epoch 29/100
# 36324/36324 [==============================] - 24s 671us/step - loss: 86.0732 - mean_squared_error: 86.0732 - val_loss: 86.6660 - val_mean_squared_error: 86.6660
#
# Epoch 00029: val_loss improved from 96.23312 to 86.66600, saving model to my_cnn_1e4.hdf5
# Epoch 30/100
# 36324/36324 [==============================] - 24s 670us/step - loss: 80.4270 - mean_squared_error: 80.4270 - val_loss: 112.6031 - val_mean_squared_error: 112.6030
#
# Epoch 00030: val_loss did not improve from 86.66600
# Epoch 31/100
# 36324/36324 [==============================] - 24s 671us/step - loss: 78.0484 - mean_squared_error: 78.0484 - val_loss: 86.4277 - val_mean_squared_error: 86.4277
#
# Epoch 00031: val_loss improved from 86.66600 to 86.42772, saving model to my_cnn_1e4.hdf5
# Epoch 32/100
# 36324/36324 [==============================] - 24s 668us/step - loss: 77.6425 - mean_squared_error: 77.6425 - val_loss: 86.6328 - val_mean_squared_error: 86.6328
#
# Epoch 00032: val_loss did not improve from 86.42772
# Epoch 33/100
# 36324/36324 [==============================] - 24s 661us/step - loss: 74.9148 - mean_squared_error: 74.9148 - val_loss: 82.8719 - val_mean_squared_error: 82.8719
#
# Epoch 00033: val_loss improved from 86.42772 to 82.87186, saving model to my_cnn_1e4.hdf5
# Epoch 34/100
# 36324/36324 [==============================] - 25s 679us/step - loss: 73.0049 - mean_squared_error: 73.0049 - val_loss: 77.7470 - val_mean_squared_error: 77.7471
#
# Epoch 00034: val_loss improved from 82.87186 to 77.74705, saving model to my_cnn_1e4.hdf5
# Epoch 35/100
# 36324/36324 [==============================] - 24s 671us/step - loss: 74.9429 - mean_squared_error: 74.9429 - val_loss: 87.4937 - val_mean_squared_error: 87.4937
#
# Epoch 00035: val_loss did not improve from 77.74705
# Epoch 36/100
# 36324/36324 [==============================] - 24s 671us/step - loss: 70.4795 - mean_squared_error: 70.4796 - val_loss: 78.6195 - val_mean_squared_error: 78.6195
#
# Epoch 00036: val_loss did not improve from 77.74705
# Epoch 37/100
# 36324/36324 [==============================] - 25s 677us/step - loss: 66.3937 - mean_squared_error: 66.3937 - val_loss: 72.7836 - val_mean_squared_error: 72.7836
#
# Epoch 00037: val_loss improved from 77.74705 to 72.78359, saving model to my_cnn_1e4.hdf5
# Epoch 38/100
# 36324/36324 [==============================] - 25s 675us/step - loss: 65.7434 - mean_squared_error: 65.7435 - val_loss: 81.8439 - val_mean_squared_error: 81.8439
#
# Epoch 00038: val_loss did not improve from 72.78359
# Epoch 39/100
# 36324/36324 [==============================] - 24s 665us/step - loss: 67.8911 - mean_squared_error: 67.8911 - val_loss: 73.7490 - val_mean_squared_error: 73.7490
#
# Epoch 00039: val_loss did not improve from 72.78359
# Epoch 40/100
# 36324/36324 [==============================] - 24s 670us/step - loss: 67.7738 - mean_squared_error: 67.7738 - val_loss: 73.4782 - val_mean_squared_error: 73.4781
#
# Epoch 00040: val_loss did not improve from 72.78359
# Epoch 41/100
# 36324/36324 [==============================] - 24s 669us/step - loss: 64.0179 - mean_squared_error: 64.0179 - val_loss: 67.9641 - val_mean_squared_error: 67.9642
#
# Epoch 00041: val_loss improved from 72.78359 to 67.96415, saving model to my_cnn_1e4.hdf5
# Epoch 42/100
# 36324/36324 [==============================] - 24s 670us/step - loss: 63.5120 - mean_squared_error: 63.5120 - val_loss: 68.5680 - val_mean_squared_error: 68.5680
#
# Epoch 00042: val_loss did not improve from 67.96415
# Epoch 43/100
# 36324/36324 [==============================] - 24s 667us/step - loss: 60.5921 - mean_squared_error: 60.5920 - val_loss: 70.7380 - val_mean_squared_error: 70.7380
#
# Epoch 00043: val_loss did not improve from 67.96415
# Epoch 44/100
# 36324/36324 [==============================] - 24s 674us/step - loss: 61.8474 - mean_squared_error: 61.8474 - val_loss: 63.7664 - val_mean_squared_error: 63.7664
#
# Epoch 00044: val_loss improved from 67.96415 to 63.76641, saving model to my_cnn_1e4.hdf5
# Epoch 45/100
# 36324/36324 [==============================] - 24s 671us/step - loss: 56.9559 - mean_squared_error: 56.9559 - val_loss: 66.2415 - val_mean_squared_error: 66.2415
#
# Epoch 00045: val_loss did not improve from 63.76641
# Epoch 46/100
# 36324/36324 [==============================] - 25s 675us/step - loss: 58.2701 - mean_squared_error: 58.2701 - val_loss: 63.4425 - val_mean_squared_error: 63.4425
#
# Epoch 00046: val_loss improved from 63.76641 to 63.44246, saving model to my_cnn_1e4.hdf5
# Epoch 47/100
# 36324/36324 [==============================] - 24s 666us/step - loss: 55.3864 - mean_squared_error: 55.3865 - val_loss: 60.0873 - val_mean_squared_error: 60.0873
#
# Epoch 00047: val_loss improved from 63.44246 to 60.08733, saving model to my_cnn_1e4.hdf5
# Epoch 48/100
# 36324/36324 [==============================] - 24s 671us/step - loss: 55.2684 - mean_squared_error: 55.2684 - val_loss: 62.7501 - val_mean_squared_error: 62.7501
#
# Epoch 00048: val_loss did not improve from 60.08733
# Epoch 49/100
# 36324/36324 [==============================] - 24s 671us/step - loss: 54.9069 - mean_squared_error: 54.9069 - val_loss: 63.2431 - val_mean_squared_error: 63.2431
#
# Epoch 00049: val_loss did not improve from 60.08733
# Epoch 50/100
# 36324/36324 [==============================] - 24s 674us/step - loss: 53.6338 - mean_squared_error: 53.6338 - val_loss: 62.3741 - val_mean_squared_error: 62.3741
#
# Epoch 00050: val_loss did not improve from 60.08733
# Epoch 51/100
# 36324/36324 [==============================] - 24s 668us/step - loss: 53.4304 - mean_squared_error: 53.4304 - val_loss: 72.8631 - val_mean_squared_error: 72.8632
#
# Epoch 00051: val_loss did not improve from 60.08733
# Epoch 52/100
# 36324/36324 [==============================] - 25s 677us/step - loss: 55.7311 - mean_squared_error: 55.7311 - val_loss: 55.7367 - val_mean_squared_error: 55.7367
#
# Epoch 00052: val_loss improved from 60.08733 to 55.73674, saving model to my_cnn_1e4.hdf5
# Epoch 53/100
# 36324/36324 [==============================] - 25s 676us/step - loss: 53.2568 - mean_squared_error: 53.2568 - val_loss: 60.1265 - val_mean_squared_error: 60.1265
#
# Epoch 00053: val_loss did not improve from 55.73674
# Epoch 54/100
# 36324/36324 [==============================] - 24s 673us/step - loss: 53.0928 - mean_squared_error: 53.0928 - val_loss: 62.2958 - val_mean_squared_error: 62.2958
#
# Epoch 00054: val_loss did not improve from 55.73674
# Epoch 55/100
# 36324/36324 [==============================] - 24s 669us/step - loss: 51.9749 - mean_squared_error: 51.9749 - val_loss: 55.5585 - val_mean_squared_error: 55.5585
#
# Epoch 00055: val_loss improved from 55.73674 to 55.55849, saving model to my_cnn_1e4.hdf5
# Epoch 56/100
# 36324/36324 [==============================] - 24s 672us/step - loss: 51.6395 - mean_squared_error: 51.6395 - val_loss: 65.3880 - val_mean_squared_error: 65.3881
#
# Epoch 00056: val_loss did not improve from 55.55849
# Epoch 57/100
# 36324/36324 [==============================] - 24s 666us/step - loss: 53.1182 - mean_squared_error: 53.1182 - val_loss: 58.1515 - val_mean_squared_error: 58.1515
#
# Epoch 00057: val_loss did not improve from 55.55849
# Epoch 58/100
# 36324/36324 [==============================] - 25s 675us/step - loss: 48.8882 - mean_squared_error: 48.8882 - val_loss: 57.4607 - val_mean_squared_error: 57.4607
#
# Epoch 00058: val_loss did not improve from 55.55849
# Epoch 59/100
# 36324/36324 [==============================] - 24s 670us/step - loss: 48.5731 - mean_squared_error: 48.5731 - val_loss: 51.7439 - val_mean_squared_error: 51.7439
#
# Epoch 00059: val_loss improved from 55.55849 to 51.74391, saving model to my_cnn_1e4.hdf5
# Epoch 60/100
# 36324/36324 [==============================] - 24s 670us/step - loss: 48.0813 - mean_squared_error: 48.0813 - val_loss: 61.8104 - val_mean_squared_error: 61.8104
#
# Epoch 00060: val_loss did not improve from 51.74391
# Epoch 61/100
# 36324/36324 [==============================] - 24s 666us/step - loss: 51.0603 - mean_squared_error: 51.0603 - val_loss: 53.2084 - val_mean_squared_error: 53.2084
#
# Epoch 00061: val_loss did not improve from 51.74391
# Epoch 62/100
# 36324/36324 [==============================] - 24s 671us/step - loss: 46.0832 - mean_squared_error: 46.0832 - val_loss: 52.1713 - val_mean_squared_error: 52.1713
#
# Epoch 00062: val_loss did not improve from 51.74391
# Epoch 63/100
# 36324/36324 [==============================] - 24s 669us/step - loss: 45.6580 - mean_squared_error: 45.6580 - val_loss: 52.8416 - val_mean_squared_error: 52.8416
#
# Epoch 00063: val_loss did not improve from 51.74391
# Epoch 64/100
# 36324/36324 [==============================] - 24s 668us/step - loss: 47.2159 - mean_squared_error: 47.2159 - val_loss: 48.4777 - val_mean_squared_error: 48.4777
#
# Epoch 00064: val_loss improved from 51.74391 to 48.47768, saving model to my_cnn_1e4.hdf5
# Epoch 65/100
# 36324/36324 [==============================] - 24s 674us/step - loss: 46.0057 - mean_squared_error: 46.0057 - val_loss: 50.0340 - val_mean_squared_error: 50.0340
#
# Epoch 00065: val_loss did not improve from 48.47768
# Epoch 66/100
# 36324/36324 [==============================] - 24s 665us/step - loss: 45.8887 - mean_squared_error: 45.8887 - val_loss: 59.2861 - val_mean_squared_error: 59.2861
#
# Epoch 00066: val_loss did not improve from 48.47768
# Epoch 67/100
# 36324/36324 [==============================] - 25s 677us/step - loss: 47.8606 - mean_squared_error: 47.8606 - val_loss: 48.9726 - val_mean_squared_error: 48.9726
#
# Epoch 00067: val_loss did not improve from 48.47768
# Epoch 68/100
# 36324/36324 [==============================] - 24s 673us/step - loss: 44.3404 - mean_squared_error: 44.3404 - val_loss: 58.4477 - val_mean_squared_error: 58.4477
#
# Epoch 00068: val_loss did not improve from 48.47768
# Epoch 69/100
# 36324/36324 [==============================] - 24s 671us/step - loss: 43.1778 - mean_squared_error: 43.1778 - val_loss: 70.4953 - val_mean_squared_error: 70.4953
#
# Epoch 00069: val_loss did not improve from 48.47768
# Epoch 70/100
# 36324/36324 [==============================] - 24s 663us/step - loss: 42.6706 - mean_squared_error: 42.6706 - val_loss: 49.5924 - val_mean_squared_error: 49.5924
#
# Epoch 00070: val_loss did not improve from 48.47768
# Epoch 71/100
# 36324/36324 [==============================] - 24s 668us/step - loss: 41.1456 - mean_squared_error: 41.1457 - val_loss: 73.1431 - val_mean_squared_error: 73.1431
#
# Epoch 00071: val_loss did not improve from 48.47768
# Epoch 72/100
# 36324/36324 [==============================] - 24s 672us/step - loss: 44.7536 - mean_squared_error: 44.7536 - val_loss: 49.2093 - val_mean_squared_error: 49.2093
#
# Epoch 00072: val_loss did not improve from 48.47768
# Epoch 73/100
# 36324/36324 [==============================] - 24s 664us/step - loss: 42.4293 - mean_squared_error: 42.4293 - val_loss: 50.4133 - val_mean_squared_error: 50.4133
#
# Epoch 00073: val_loss did not improve from 48.47768
# Epoch 74/100
# 36324/36324 [==============================] - 24s 665us/step - loss: 41.1173 - mean_squared_error: 41.1173 - val_loss: 53.2165 - val_mean_squared_error: 53.2165
#
# Epoch 00074: val_loss did not improve from 48.47768
# Epoch 75/100
# 36324/36324 [==============================] - 24s 672us/step - loss: 42.1537 - mean_squared_error: 42.1537 - val_loss: 51.7475 - val_mean_squared_error: 51.7475
#
# Epoch 00075: val_loss did not improve from 48.47768
# Epoch 76/100
# 36324/36324 [==============================] - 24s 665us/step - loss: 39.5138 - mean_squared_error: 39.5138 - val_loss: 50.2885 - val_mean_squared_error: 50.2885
#
# Epoch 00076: val_loss did not improve from 48.47768
# Epoch 77/100
# 36324/36324 [==============================] - 24s 663us/step - loss: 39.3920 - mean_squared_error: 39.3920 - val_loss: 47.8644 - val_mean_squared_error: 47.8644
#
# Epoch 00077: val_loss improved from 48.47768 to 47.86444, saving model to my_cnn_1e4.hdf5
# Epoch 78/100
# 36324/36324 [==============================] - 24s 666us/step - loss: 39.6579 - mean_squared_error: 39.6579 - val_loss: 49.2049 - val_mean_squared_error: 49.2049
#
# Epoch 00078: val_loss did not improve from 47.86444
# Epoch 79/100
# 36324/36324 [==============================] - 24s 668us/step - loss: 40.0112 - mean_squared_error: 40.0112 - val_loss: 58.4086 - val_mean_squared_error: 58.4086
#
# Epoch 00079: val_loss did not improve from 47.86444
# Epoch 80/100
# 36324/36324 [==============================] - 24s 662us/step - loss: 43.2402 - mean_squared_error: 43.2402 - val_loss: 61.6638 - val_mean_squared_error: 61.6638
#
# Epoch 00080: val_loss did not improve from 47.86444
# Epoch 81/100
# 36324/36324 [==============================] - 24s 671us/step - loss: 36.3648 - mean_squared_error: 36.3648 - val_loss: 61.7671 - val_mean_squared_error: 61.7671
#
# Epoch 00081: val_loss did not improve from 47.86444
# Epoch 82/100
# 36324/36324 [==============================] - 24s 670us/step - loss: 38.5049 - mean_squared_error: 38.5049 - val_loss: 54.7576 - val_mean_squared_error: 54.7576
#
# Epoch 00082: val_loss did not improve from 47.86444
# Epoch 83/100
# 36324/36324 [==============================] - 24s 664us/step - loss: 38.7615 - mean_squared_error: 38.7615 - val_loss: 51.0095 - val_mean_squared_error: 51.0095
#
# Epoch 00083: val_loss did not improve from 47.86444
# Epoch 84/100
# 36324/36324 [==============================] - 24s 663us/step - loss: 38.9732 - mean_squared_error: 38.9732 - val_loss: 55.7336 - val_mean_squared_error: 55.7336
#
# Epoch 00084: val_loss did not improve from 47.86444
# Epoch 85/100
# 36324/36324 [==============================] - 24s 670us/step - loss: 40.7479 - mean_squared_error: 40.7479 - val_loss: 42.9618 - val_mean_squared_error: 42.9618
#
# Epoch 00085: val_loss improved from 47.86444 to 42.96178, saving model to my_cnn_1e4.hdf5
# Epoch 86/100
# 36324/36324 [==============================] - 24s 661us/step - loss: 35.1881 - mean_squared_error: 35.1881 - val_loss: 65.4830 - val_mean_squared_error: 65.4829
#
# Epoch 00086: val_loss did not improve from 42.96178
# Epoch 87/100
# 36324/36324 [==============================] - 24s 668us/step - loss: 39.3841 - mean_squared_error: 39.3841 - val_loss: 45.2110 - val_mean_squared_error: 45.2110
#
# Epoch 00087: val_loss did not improve from 42.96178
# Epoch 88/100
# 36324/36324 [==============================] - 24s 664us/step - loss: 38.6386 - mean_squared_error: 38.6386 - val_loss: 64.9510 - val_mean_squared_error: 64.9510
#
# Epoch 00088: val_loss did not improve from 42.96178
# Epoch 89/100
# 36324/36324 [==============================] - 25s 675us/step - loss: 36.2511 - mean_squared_error: 36.2511 - val_loss: 45.8569 - val_mean_squared_error: 45.8569
#
# Epoch 00089: val_loss did not improve from 42.96178
# Epoch 90/100
# 36324/36324 [==============================] - 24s 673us/step - loss: 38.1689 - mean_squared_error: 38.1689 - val_loss: 44.0106 - val_mean_squared_error: 44.0106
#
# Epoch 00090: val_loss did not improve from 42.96178
# Epoch 91/100
# 36324/36324 [==============================] - 24s 670us/step - loss: 36.2775 - mean_squared_error: 36.2775 - val_loss: 53.8571 - val_mean_squared_error: 53.8571
#
# Epoch 00091: val_loss did not improve from 42.96178
# Epoch 92/100
# 36324/36324 [==============================] - 24s 666us/step - loss: 37.7746 - mean_squared_error: 37.7746 - val_loss: 46.2730 - val_mean_squared_error: 46.2730
#
# Epoch 00092: val_loss did not improve from 42.96178
# Epoch 93/100
# 36324/36324 [==============================] - 24s 667us/step - loss: 32.4996 - mean_squared_error: 32.4996 - val_loss: 73.2323 - val_mean_squared_error: 73.2323
#
# Epoch 00093: val_loss did not improve from 42.96178
# Epoch 94/100
# 36324/36324 [==============================] - 24s 662us/step - loss: 38.4579 - mean_squared_error: 38.4579 - val_loss: 44.0537 - val_mean_squared_error: 44.0537
#
# Epoch 00094: val_loss did not improve from 42.96178
# Epoch 95/100
# 36324/36324 [==============================] - 25s 675us/step - loss: 34.7466 - mean_squared_error: 34.7466 - val_loss: 47.4106 - val_mean_squared_error: 47.4106
#
# Epoch 00095: val_loss did not improve from 42.96178
# Epoch 96/100
# 36324/36324 [==============================] - 25s 682us/step - loss: 35.7961 - mean_squared_error: 35.7961 - val_loss: 52.8827 - val_mean_squared_error: 52.8827
#
# Epoch 00096: val_loss did not improve from 42.96178
# Epoch 97/100
# 36324/36324 [==============================] - 24s 670us/step - loss: 34.5028 - mean_squared_error: 34.5028 - val_loss: 41.6132 - val_mean_squared_error: 41.6132
#
# Epoch 00097: val_loss improved from 42.96178 to 41.61325, saving model to my_cnn_1e4.hdf5
# Epoch 98/100
# 36324/36324 [==============================] - 24s 667us/step - loss: 34.0898 - mean_squared_error: 34.0898 - val_loss: 48.7847 - val_mean_squared_error: 48.7847
#
# Epoch 00098: val_loss did not improve from 41.61325
# Epoch 99/100
# 36324/36324 [==============================] - 24s 663us/step - loss: 34.5019 - mean_squared_error: 34.5019 - val_loss: 46.8765 - val_mean_squared_error: 46.8765
#
# Epoch 00099: val_loss did not improve from 41.61325
# Epoch 100/100
# 36324/36324 [==============================] - 24s 664us/step - loss: 33.1238 - mean_squared_error: 33.1238 - val_loss: 47.7754 - val_mean_squared_error: 47.7754
#
# Epoch 00100: val_loss did not improve from 41.61325

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(3, 3), dpi=300, facecolor='w', edgecolor='k')

plt.plot(history1.history['loss'], color = 'red')
plt.plot(history1.history['val_loss'], color = 'green')
plt.title('Our end to end model with 1e4 learning rate')
plt.ylabel('Mean Squared Error')
plt.xlabel('Epochs')
plt.legend(['training_loss', 'validation_loss'], loc='upper right')
plt.savefig('MYMODEL_END_TO_END_1E4.png', dpi=300, bbox_inches='tight')
plt.show()
